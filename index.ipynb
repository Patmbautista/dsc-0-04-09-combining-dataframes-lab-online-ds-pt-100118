# %% [markdown]
# # Combining DataFrames With Pandas - Lab
#
# ## Introduction
#
# In this lab, we'll gain practice combining DataFrames through concatenation.  We'll also learn to read in tables from a database and store them in separate tables, as well as how to execute various types of joins to selectively combine the information stored in the tables!
#
#
# ## Objectives:
# You will be able to:
# * Understand and explain when to use DataFrame joins and merges
# * Be able to use pd.merge when combining DataFrames based on column values
# * Understand, explain and use a range of DataFrame merge types: outer, inner, left and right
# * Use pd.concat() to stack DataFrames
#
# ## Getting Started
#
# We'll start with a quick section to help us gain practice with concatenating datasets using `pd.concat()`.
#
# ### Concatenating DataFrames
#
# Run the cell below to create some sample DataFrames for us to work with.

# %%
import pandas as pd
df1 = pd.DataFrame({'A': ['A0', 'A1', 'A2', 'A3'],
                    'B': ['B0', 'B1', 'B2', 'B3'],
                    'C': ['C0', 'C1', 'C2', 'C3'],
                    'D': ['D0', 'D1', 'D2', 'D3']},
                    index=[0, 1, 2, 3])


df2 = pd.DataFrame({'A': ['A4', 'A5', 'A6', 'A7'],
                    'B': ['B4', 'B5', 'B6', 'B7'],
                    'C': ['C4', 'C5', 'C6', 'C7'],
                    'D': ['D4', 'D5', 'D6', 'D7']},
                    index=[4, 5, 6, 7])

df3 = pd.DataFrame({'A': ['A8', 'A9', 'A10', 'A11'],
                    'B': ['B8', 'B9', 'B10', 'B11'],
                    'C': ['C8', 'C9', 'C10', 'C11'], 
                    'D': ['D8', 'D9', 'D10', 'D11']},
                    index=[8, 9, 10, 11])

# %% [markdown]
# Now that we have multiple DataFrames to work with, we can execute a concatenation to join them together.
#
# In the cell below, concatenate the 3 DataFrames together using the appropriate function.

# %%
to_concat = [df1, df2, df3]
combined_df = pd.concat(to_concat)
combined_df
# Out:
#       A    B    C    D
# 0    A0   B0   C0   D0
# 1    A1   B1   C1   D1
# 2    A2   B2   C2   D2
# 3    A3   B3   C3   D3
# 4    A4   B4   C4   D4
# 5    A5   B5   C5   D5
# 6    A6   B6   C6   D6
# 7    A7   B7   C7   D7
# 8    A8   B8   C8   D8
# 9    A9   B9   C9   D9
# 10  A10  B10  C10  D10
# 11  A11  B11  C11  D11

# %% [markdown]
# **_EXPECTED OUTPUT:_**
#
# <img src="er1.png">
#
# ### Setting Join Conditions With Concatenation
#
# We can also specify if the concatenation is an **_Outer Join_** or an **_Inner Join_**.  Next, we'll execute an inner join. Before we do, we need to create another table that contains some overlapping index values with a DataFrame that already exists.
#
# Run the cell below to create the new DataFrame.

# %%
df4 = pd.DataFrame({'B': ['B2', 'B3', 'B6', 'B7'],
                    'D': ['D2', 'D3', 'D6', 'D7'],
                    'F': ['F2', 'F3', 'F6', 'F7']},
                    index=[2, 3, 6, 7])

# %% [markdown]
# Now, in the cell below, use the `pd.concat()` method to join DataFrames 1 and 4.  However, this time, specify that the `join` is `'inner'`, and `axis=1`.

# %%
df1_and_4 = pd.concat([df1, df4], axis=1, join='inner')
df1_and_4
# Out:
#     A   B   C   D   B   D   F
# 2  A2  B2  C2  D2  B2  D2  F2
# 3  A3  B3  C3  D3  B3  D3  F3

# %% [markdown]
# **_EXPECTED OUTPUT:_**
#
# <img src='er2.png'>
#
# We'll notice that in this case, the results returned contain only the rows with indexes that exist in both tables--rows 2 and 3.  The resulting table contains the values for each column in both tables for the rows.
#
# Note that there are many, many ways that we can make full use of the `concat()` functionality in pandas to join DataFrames together--these are just a few of the most common examples pulled from the pandas documentation on the subject.  For a full view of all the ways we can use `pd.concat()`, see the [pandas documentation](http://pandas.pydata.org/pandas-docs/stable/merging.html)!

# %% [markdown]
# ## Loading In Data From SQL Database Tables
#
# Now, we'll move on to working with the Hearthstone cards database.  This database contains information on cards from the popular game, [Hearthstone](https://playhearthstone.com/en-us/)! For full information on the dataset, see the  [kaggle page](https://www.kaggle.com/jeradrose/hearthstone-cards) for this dataset.
#
# This database consists of the following tables:
#
# * _cards_
# * *dust_costs*
# * _entourages_
# * _mechanics_
# * *play_requirements*
#
# Many of rows in each table--but not all--correspond to the same cards. As such, each table contains a column called `card_id` which acts as a **_Primary Key_** for each table.  We'll make use of these keys to **_join_** the different tables together into a single DataFrame.  We'll also experiment with different types of joins to help us decide exactly what information we want to combine.
#
# Before we can begin working with the database, we'll first need to connect to it.  For this, we'll use the `sqlalchemy` library.
#
# In the cell below:
#
# * Import the `create_engine` module from `sqlalchemy`
# * Create an engine that connects to `sqlite:///database.sqlite`.

# %%
from sqlalchemy import create_engine
engine = create_engine('sqlite:///database.sqlite')

# %% [markdown]
# Now that we've successfully connected to our Database, we'll make use of pandas to read in each table individually.
#
# In the cell below, read in each sql table into separate pandas DataFrames using the `read_sql_table` method.
#
# The first argument should be a string corresponding to the name of the table, and the second argument should be the `engine` object we created in the cell above.
#
# If you're unsure of how to do this, see the [documentation](https://pandas.pydata.org/pandas-docs/stable/generated/pandas.read_sql_table.html).

# %%
cards_df = pd.read_sql_table('cards', engine)
dust_df = pd.read_sql_table('dust_costs', engine)
entourages_df = pd.read_sql_table('entourages', engine)
mechanics_df = pd.read_sql_table('mechanics', engine)
play_requirements_df = pd.read_sql_table('play_requirements', engine)

# %% [markdown]
# Great.  Now, let's set the correct column, `card_id`, as the index column for each of these tables, and then display each to ensure that everything is as expected.
#
# For each of the dataframes we created in the cell above, call the `.set_index()` method and pass in `card_id`.  Also set `inplace=True`.  Then, display the head of each respective DataFrame to ensure everything worked.
#
# **_NOTE:_** Since we are performing this operation in place, running any cell a second time will result in pandas throwing an error.  If you need to run something a second time, restart the kernel using the jupyter notebook menu at the top of the page.

# %%
cards_df.set_index('card_id', inplace=True)
cards_df.head()
# Out:
#            player_class    type                name      set  \
# card_id
# KARA_00_07         MAGE   SPELL       Astral Portal     KARA
# NEW1_008a         DRUID   SPELL   Ancient Teachings  EXPERT1
# BRM_010t2         DRUID  MINION  Druid of the Flame      BRM
# AT_132          NEUTRAL  MINION  Justicar Trueheart      TGT
# OG_141          NEUTRAL  MINION   Faceless Behemoth       OG
#
#                                                          text  cost  attack  \
# card_id
# KARA_00_07           Summon a random <b>Legendary</b> minion.   1.0     NaN
# NEW1_008a                                        Draw a card.   0.0     NaN
# BRM_010t2                                                None   3.0     2.0
# AT_132      <b>Battlecry:</b> Replace your starting Hero P...   6.0     6.0
# OG_141                                                   None  10.0    10.0
#
#             health     rarity  collectible  \
# card_id
# KARA_00_07     NaN       None          NaN
# NEW1_008a      NaN       None          NaN
# BRM_010t2      5.0     COMMON          NaN
# AT_132         3.0  LEGENDARY          1.0
# OG_141        10.0     COMMON          1.0
#
#                                                        flavor   race  \
# card_id
# KARA_00_07                                               None   None
# NEW1_008a                                                None   None
# BRM_010t2                                                None  BEAST
# AT_132      It's like putting racing stripes and a giant s...   None
# OG_141      Rejected names: Forty-Foot Faceless, Big ol' N...   None
#
#            how_to_earn how_to_earn_golden targeting_arrow_text faction  \
# card_id
# KARA_00_07        None               None                 None    None
# NEW1_008a         None               None                 None    None
# BRM_010t2         None               None                 None    None
# AT_132            None               None                 None    None
# OG_141            None               None                 None    None
#
#             durability
# card_id
# KARA_00_07         NaN
# NEW1_008a          NaN
# BRM_010t2          NaN
# AT_132             NaN
# OG_141             NaN

# %%
dust_df.set_index('card_id', inplace=True)
dust_df.head()
# Out:
#                       action  cost
# card_id
# BRM_010t2    CRAFTING_NORMAL    40
# BRM_010t2    CRAFTING_GOLDEN   400
# BRM_010t2  DISENCHANT_NORMAL     5
# BRM_010t2  DISENCHANT_GOLDEN    50
# AT_132       CRAFTING_NORMAL  1600

# %%
entourages_df.set_index('card_id', inplace=True)
entourages_df.head()
# Out:
#            entourage_card_id
# card_id
# KAR_A10_22        KAR_A10_09
# KAR_A10_22        KAR_A10_02
# KAR_A10_22        KAR_A10_08
# KAR_A10_22        KAR_A10_04
# KAR_A10_22        KAR_A10_05

# %%
mechanics_df.set_index('card_id', inplace=True)
mechanics_df.head()
# Out:
#                      mechanic
# card_id
# AT_132              BATTLECRY
# GVG_011a  TAG_ONE_TURN_EFFECT
# EX1_583             BATTLECRY
# LOE_007t            EVIL_GLOW
# LOE_007t   ImmuneToSpellpower

# %%
play_requirements_df.set_index('card_id', inplace=True)
play_requirements_df.head()
# Out:
#                      play_requirement  value
# card_id
# KARA_00_07       REQ_NUM_MINION_SLOTS      1
# PRO_001a         REQ_NUM_MINION_SLOTS      1
# NAX1_01          REQ_NUM_MINION_SLOTS      1
# DS1h_292_H1           REQ_STEADY_SHOT      0
# DS1h_292_H1  REQ_MINION_OR_ENEMY_HERO      0

# %% [markdown]
# ### Executing Joins
#
# Now that we have the tables loaded correctly, we're going to execute some joins. There are 4 different kinds of joins, which can best be visualized with venn diagrams:
#
# <img src='joins.png'>
#
# In these diagrams, each circle represents a DataFrame or SQL Table.  The left table is the table we are working with, and the right table is the table we want to join to the table we are working with.  We'll start by executing the most common type of join, an **_Inner Join_**.
#
# In the cell below, join `cards_df` with `mechanics_df` using the built-in `.join()` method on the `cards_df` object.
#
# Pass in the following parameters:
# * the table we want to join with, `mechanics_df`
# * The `how` parameter set to the type of join we want, `'inner'`

# %%
cards_with_mechanics_df = cards_df.join(mechanics_df, how='inner')
cards_with_mechanics_df
# Out:
# ValueErrorTraceback (most recent call last)
# <ipython-input-12-62a4ed9f1a2d> in <module>()
# ----> 1 cards_with_mechanics_df = cards_df.join(mechanics_df, how='inner')
#       2 cards_with_mechanics_df
#
# /opt/conda/envs/learn-env/lib/python3.6/site-packages/pandas/core/frame.py in join(self, other, on, how, lsuffix, rsuffix, sort)
#    6334         # For SparseDataFrame's benefit
#    6335         return self._join_compat(other, on=on, how=how, lsuffix=lsuffix,
# -> 6336                                  rsuffix=rsuffix, sort=sort)
#    6337
#    6338     def _join_compat(self, other, on=None, how='left', lsuffix='', rsuffix='',
#
# /opt/conda/envs/learn-env/lib/python3.6/site-packages/pandas/core/frame.py in _join_compat(self, other, on, how, lsuffix, rsuffix, sort)
#    6349             return merge(self, other, left_on=on, how=how,
#    6350                          left_index=on is None, right_index=True,
# -> 6351                          suffixes=(lsuffix, rsuffix), sort=sort)
#    6352         else:
#    6353             if on is not None:
#
# /opt/conda/envs/learn-env/lib/python3.6/site-packages/pandas/core/reshape/merge.py in merge(left, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#      60                          copy=copy, indicator=indicator,
#      61                          validate=validate)
# ---> 62     return op.get_result()
#      63
#      64
#
# /opt/conda/envs/learn-env/lib/python3.6/site-packages/pandas/core/reshape/merge.py in get_result(self)
#     572
#     573         llabels, rlabels = items_overlap_with_suffix(ldata.items, lsuf,
# --> 574                                                      rdata.items, rsuf)
#     575
#     576         lindexers = {1: left_indexer} if left_indexer is not None else {}
#
# /opt/conda/envs/learn-env/lib/python3.6/site-packages/pandas/core/internals.py in items_overlap_with_suffix(left, lsuffix, right, rsuffix)
#    5242         if not lsuffix and not rsuffix:
#    5243             raise ValueError('columns overlap but no suffix specified: '
# -> 5244                              '{rename}'.format(rename=to_rename))
#    5245
#    5246         def lrenamer(x):
#
# ValueError: columns overlap but no suffix specified: Index(['card_id'], dtype='object')

# %% [markdown]
# Examine the output from the cell above and compare it to the original output of both the `cards_df` and `mechanics_df` DataFrame heads we displayed earlier.  Notice how it this now combines the columns from both?
#
# **_Question_**
#
# If you inspect the original `cards_df` DataFrame, you'll notice that it contains  2,819 records.  The result of our inner join, `cards_with_mechanics_df`, conntains only 1079 rows.  Why?
#
# Write your answer below this line:
# ________________________________________________________________________________
#
#
# ### Other Types of Joins
#
# By default, the `.join()` method performs a left join if no parameter is passed in for `how=`.  In the cell below, perform a **_Left Join_** of `cards_with_mechanics_df` and `play_requirements_df`, with `cards_with_mechanics_df` as the left table.
#
# Then, display `left_join_df` to inspect our results.

# %%
left_join_df = cards_with_mechanics.join(play_requirements)
left_join_df
# Out:
# NameErrorTraceback (most recent call last)
# <ipython-input-11-edc1ff766c3e> in <module>()
# ----> 1 left_join_df = cards_with_mechanics.join(play_requirements)
#       2 left_join_df
#
# NameError: name 'cards_with_mechanics' is not defined

# %% [markdown]
# Note that the results of this sort of join are dependent upon the position of each table--if we were to make `cards_with_mechanics_df` the right table and `play_requirements_df` the left table and then perform a **_Right Join_**, our results would be the same.
#
# **_Question:_**
#
# Describe what was included from each table in this join.
#
# Write your answer below this line:
# ________________________________________________________________________________
#
#
#
# #### Outer Joins
#
# In the cell below, perform an outer join between `cards_df` and `dust_df`. Since these tables contain columns with the same name, we'll need to specify a suffix for at least one of them, so that the column can be renamed to avoid a naming collision.
#
# During this join, set the `rsuffix` parameter to `_dust`

# %%
outer_join_df = cards_df.join(dust_df, rsuffix='_dust', how='outer')
outer_join_df
# Out:
#                           card_id player_class         type  \
# 0                      KARA_00_07         MAGE        SPELL
# 1                       NEW1_008a        DRUID        SPELL
# 2                       BRM_010t2        DRUID       MINION
# 3                          AT_132      NEUTRAL       MINION
# 4                          OG_141      NEUTRAL       MINION
# 5                         CRED_17      NEUTRAL       MINION
# 6                         OG_337e      NEUTRAL  ENCHANTMENT
# 7                       BRMA08_1H      NEUTRAL         HERO
# 8                        GVG_011a      NEUTRAL  ENCHANTMENT
# 9                     NAX8_02H_TB      NEUTRAL   HERO_POWER
# 10                         AT_131      NEUTRAL       MINION
# 11                       CS2_122e      NEUTRAL  ENCHANTMENT
# 12                    LOEA05_02ha      NEUTRAL   HERO_POWER
# 13              CS2_102_H1_AT_132      WARRIOR   HERO_POWER
# 14                       CFM_334e      NEUTRAL  ENCHANTMENT
# 15                        EX1_583      NEUTRAL       MINION
# 16         TB_PickYourFate_11rand      NEUTRAL        SPELL
# 17                       LOE_007t      WARLOCK        SPELL
# 18                        CFM_095      NEUTRAL       MINION
# 19                        BRM_018      PALADIN       MINION
# 20                       PRO_001a      NEUTRAL        SPELL
# 21                      BRMA10_5H      NEUTRAL       MINION
# 22                       BRMA11_1      NEUTRAL         HERO
# 23                         OG_027       SHAMAN        SPELL
# 24                        NAX1_01      NEUTRAL         HERO
# 25                        GVG_030        DRUID       MINION
# 26                        CFM_094      WARLOCK        SPELL
# 27                    DS1h_292_H1       HUNTER   HERO_POWER
# 28                        CS2_227      NEUTRAL       MINION
# 29                        KAR_062      NEUTRAL       MINION
# ...                           ...          ...          ...
# OG_338                        NaN          NaN          NaN
# OG_338                        NaN          NaN          NaN
# OG_339                        NaN          NaN          NaN
# OG_339                        NaN          NaN          NaN
# OG_339                        NaN          NaN          NaN
# OG_339                        NaN          NaN          NaN
# OG_340                        NaN          NaN          NaN
# OG_340                        NaN          NaN          NaN
# OG_340                        NaN          NaN          NaN
# OG_340                        NaN          NaN          NaN
# TB_OG_027                     NaN          NaN          NaN
# TB_OG_027                     NaN          NaN          NaN
# TB_OG_027                     NaN          NaN          NaN
# TB_OG_027                     NaN          NaN          NaN
# skele21                       NaN          NaN          NaN
# skele21                       NaN          NaN          NaN
# skele21                       NaN          NaN          NaN
# skele21                       NaN          NaN          NaN
# tt_004                        NaN          NaN          NaN
# tt_004                        NaN          NaN          NaN
# tt_004                        NaN          NaN          NaN
# tt_004                        NaN          NaN          NaN
# tt_010                        NaN          NaN          NaN
# tt_010                        NaN          NaN          NaN
# tt_010                        NaN          NaN          NaN
# tt_010                        NaN          NaN          NaN
# tt_010a                       NaN          NaN          NaN
# tt_010a                       NaN          NaN          NaN
# tt_010a                       NaN          NaN          NaN
# tt_010a                       NaN          NaN          NaN
#
#                               name         set  \
# 0                    Astral Portal        KARA
# 1                Ancient Teachings     EXPERT1
# 2               Druid of the Flame         BRM
# 3               Justicar Trueheart         TGT
# 4                Faceless Behemoth          OG
# 5                        Rob Pardo     CREDITS
# 6               Eve of Destruction          OG
# 7               General Drakkisath         BRM
# 8                       Shrink Ray         GVG
# 9                          Harvest          TB
# 10                  Eydis Darkbane         TGT
# 11                        Enhanced        CORE
# 12             Trogg Hate Minions!         LOE
# 13                        Tank Up!  HERO_SKINS
# 14                       Smuggling       GANGS
# 15              Priestess of Elune     EXPERT1
# 16              Dire Fate: Murlocs          TB
# 17                         Cursed!         LOE
# 18                 Weasel Tunneler       GANGS
# 19                  Dragon Consort         BRM
# 20                     I Am Murloc       PROMO
# 21                 Chromatic Drake         BRM
# 22         Vaelastrasz the Corrupt         BRM
# 23                          Evolve          OG
# 24                     Anub'Rekhan        NAXX
# 25               Anodized Robo Cub         GVG
# 26                  Felfire Potion       GANGS
# 27                     Steady Shot  HERO_SKINS
# 28           Venture Co. Mercenary     EXPERT1
# 29           Netherspite Historian        KARA
# ...                            ...         ...
# OG_338                         NaN         NaN
# OG_338                         NaN         NaN
# OG_339                         NaN         NaN
# OG_339                         NaN         NaN
# OG_339                         NaN         NaN
# OG_339                         NaN         NaN
# OG_340                         NaN         NaN
# OG_340                         NaN         NaN
# OG_340                         NaN         NaN
# OG_340                         NaN         NaN
# TB_OG_027                      NaN         NaN
# TB_OG_027                      NaN         NaN
# TB_OG_027                      NaN         NaN
# TB_OG_027                      NaN         NaN
# skele21                        NaN         NaN
# skele21                        NaN         NaN
# skele21                        NaN         NaN
# skele21                        NaN         NaN
# tt_004                         NaN         NaN
# tt_004                         NaN         NaN
# tt_004                         NaN         NaN
# tt_004                         NaN         NaN
# tt_010                         NaN         NaN
# tt_010                         NaN         NaN
# tt_010                         NaN         NaN
# tt_010                         NaN         NaN
# tt_010a                        NaN         NaN
# tt_010a                        NaN         NaN
# tt_010a                        NaN         NaN
# tt_010a                        NaN         NaN
#
#                                                         text  cost  attack  \
# 0                   Summon a random <b>Legendary</b> minion.   1.0     NaN
# 1                                               Draw a card.   0.0     NaN
# 2                                                       None   3.0     2.0
# 3          <b>Battlecry:</b> Replace your starting Hero P...   6.0     6.0
# 4                                                       None  10.0    10.0
# 5          You can't start a game without this minion in ...   9.0     9.0
# 6                                           Stats increased.   NaN     NaN
# 7                                                       None   NaN     NaN
# 8                                       -2 Attack this turn.   NaN     NaN
# 9          <b>Hero Power</b>\nDraw a card. Gain a Mana Cr...   2.0     NaN
# 10         Whenever <b>you</b> target this minion with a ...   3.0     3.0
# 11            Raid Leader is granting this minion +1 Attack.   NaN     NaN
# 12         <b>Passive Hero Power</b>\n Enemy minions cost...   0.0     NaN
# 13                          <b>Hero Power</b>\nGain 4 Armor.   2.0     NaN
# 14                              +2/+2 from Smuggler's Crate.   NaN     NaN
# 15          <b>Battlecry:</b> Restore 4 Health to your hero.   6.0     5.0
# 16               Turn each minion in play into a 1/1 Murloc.   0.0     NaN
# 17         While this is in your hand, take 2 damage at t...   2.0     NaN
# 18         <b>Deathrattle:</b> Shuffle this minion into y...   1.0     1.0
# 19         <b>Battlecry:</b> The next Dragon you play cos...   5.0     5.0
# 20                  Summon three, four, or five 1/1 Murlocs.   4.0     NaN
# 21                                                      None   4.0     7.0
# 22                                                      None   NaN     NaN
# 23         Transform your minions into random minions tha...   1.0     NaN
# 24                                                      None   NaN     NaN
# 25         <b>Taunt</b>. <b>Choose One -</b>\n+1 Attack; ...   2.0     2.0
# 26                         Deal $5 damage to all characters.   6.0     NaN
# 27         <b>Hero Power</b>\nDeal $2 damage to the enemy...   2.0     NaN
# 28                               Your minions cost (3) more.   5.0     7.0
# 29         <b>Battlecry:</b> If you're holding a Dragon, ...   2.0     1.0
# ...                                                      ...   ...     ...
# OG_338                                                   NaN   NaN     NaN
# OG_338                                                   NaN   NaN     NaN
# OG_339                                                   NaN   NaN     NaN
# OG_339                                                   NaN   NaN     NaN
# OG_339                                                   NaN   NaN     NaN
# OG_339                                                   NaN   NaN     NaN
# OG_340                                                   NaN   NaN     NaN
# OG_340                                                   NaN   NaN     NaN
# OG_340                                                   NaN   NaN     NaN
# OG_340                                                   NaN   NaN     NaN
# TB_OG_027                                                NaN   NaN     NaN
# TB_OG_027                                                NaN   NaN     NaN
# TB_OG_027                                                NaN   NaN     NaN
# TB_OG_027                                                NaN   NaN     NaN
# skele21                                                  NaN   NaN     NaN
# skele21                                                  NaN   NaN     NaN
# skele21                                                  NaN   NaN     NaN
# skele21                                                  NaN   NaN     NaN
# tt_004                                                   NaN   NaN     NaN
# tt_004                                                   NaN   NaN     NaN
# tt_004                                                   NaN   NaN     NaN
# tt_004                                                   NaN   NaN     NaN
# tt_010                                                   NaN   NaN     NaN
# tt_010                                                   NaN   NaN     NaN
# tt_010                                                   NaN   NaN     NaN
# tt_010                                                   NaN   NaN     NaN
# tt_010a                                                  NaN   NaN     NaN
# tt_010a                                                  NaN   NaN     NaN
# tt_010a                                                  NaN   NaN     NaN
# tt_010a                                                  NaN   NaN     NaN
#
#            health     rarity  collectible  \
# 0             NaN       None          NaN
# 1             NaN       None          NaN
# 2             5.0     COMMON          NaN
# 3             3.0  LEGENDARY          1.0
# 4            10.0     COMMON          1.0
# 5             9.0  LEGENDARY          NaN
# 6             NaN       None          NaN
# 7            50.0       None          NaN
# 8             NaN       None          NaN
# 9             NaN       None          NaN
# 10            4.0  LEGENDARY          1.0
# 11            NaN       None          NaN
# 12            NaN       None          NaN
# 13            NaN       None          NaN
# 14            NaN       None          NaN
# 15            4.0     COMMON          1.0
# 16            NaN       None          NaN
# 17            NaN       None          NaN
# 18            1.0       EPIC          1.0
# 19            5.0       RARE          1.0
# 20            NaN       None          NaN
# 21            7.0       None          NaN
# 22           30.0       None          NaN
# 23            NaN       RARE          1.0
# 24           30.0       None          NaN
# 25            2.0     COMMON          1.0
# 26            NaN       RARE          1.0
# 27            NaN       FREE          NaN
# 28            6.0     COMMON          1.0
# 29            3.0     COMMON          1.0
# ...           ...        ...          ...
# OG_338        NaN        NaN          NaN
# OG_338        NaN        NaN          NaN
# OG_339        NaN        NaN          NaN
# OG_339        NaN        NaN          NaN
# OG_339        NaN        NaN          NaN
# OG_339        NaN        NaN          NaN
# OG_340        NaN        NaN          NaN
# OG_340        NaN        NaN          NaN
# OG_340        NaN        NaN          NaN
# OG_340        NaN        NaN          NaN
# TB_OG_027     NaN        NaN          NaN
# TB_OG_027     NaN        NaN          NaN
# TB_OG_027     NaN        NaN          NaN
# TB_OG_027     NaN        NaN          NaN
# skele21       NaN        NaN          NaN
# skele21       NaN        NaN          NaN
# skele21       NaN        NaN          NaN
# skele21       NaN        NaN          NaN
# tt_004        NaN        NaN          NaN
# tt_004        NaN        NaN          NaN
# tt_004        NaN        NaN          NaN
# tt_004        NaN        NaN          NaN
# tt_010        NaN        NaN          NaN
# tt_010        NaN        NaN          NaN
# tt_010        NaN        NaN          NaN
# tt_010        NaN        NaN          NaN
# tt_010a       NaN        NaN          NaN
# tt_010a       NaN        NaN          NaN
# tt_010a       NaN        NaN          NaN
# tt_010a       NaN        NaN          NaN
#
#                                                       flavor        race  \
# 0                                                       None        None
# 1                                                       None        None
# 2                                                       None       BEAST
# 3          It's like putting racing stripes and a giant s...        None
# 4          Rejected names: Forty-Foot Faceless, Big ol' N...        None
# 5                                                       None        None
# 6                                                       None        None
# 7                                                       None        None
# 8                                                       None        None
# 9                                                       None        None
# 10                    HATES being called "the wonder twins".        None
# 11                                                      None        None
# 12                                                      None        None
# 13                                                      None        None
# 14                                                      None        None
# 15         If she threatens to "moon" you, it's not what ...        None
# 16                                                      None        None
# 17                                                      None        None
# 18         He's the reason the First Bank of Gadgetzan ha...       BEAST
# 19         Everybody wants someone to snuggle with. Even ...      DRAGON
# 20                                                      None        None
# 21                                                      None      DRAGON
# 22                                                      None        None
# 23         So you say you want an evolution. Well, you kn...        None
# 24                                                      None        None
# 25         It's adorable! AND OH MY GOODNESS WHY IS IT EA...  MECHANICAL
# 26         Kazakus has a squad of imps bottling Felfire r...        None
# 27                                                      None        None
# 28                    No Job is too big.  No fee is too big.        None
# 29         She can tell you all about the history of peop...        None
# ...                                                      ...         ...
# OG_338                                                   NaN         NaN
# OG_338                                                   NaN         NaN
# OG_339                                                   NaN         NaN
# OG_339                                                   NaN         NaN
# OG_339                                                   NaN         NaN
# OG_339                                                   NaN         NaN
# OG_340                                                   NaN         NaN
# OG_340                                                   NaN         NaN
# OG_340                                                   NaN         NaN
# OG_340                                                   NaN         NaN
# TB_OG_027                                                NaN         NaN
# TB_OG_027                                                NaN         NaN
# TB_OG_027                                                NaN         NaN
# TB_OG_027                                                NaN         NaN
# skele21                                                  NaN         NaN
# skele21                                                  NaN         NaN
# skele21                                                  NaN         NaN
# skele21                                                  NaN         NaN
# tt_004                                                   NaN         NaN
# tt_004                                                   NaN         NaN
# tt_004                                                   NaN         NaN
# tt_004                                                   NaN         NaN
# tt_010                                                   NaN         NaN
# tt_010                                                   NaN         NaN
# tt_010                                                   NaN         NaN
# tt_010                                                   NaN         NaN
# tt_010a                                                  NaN         NaN
# tt_010a                                                  NaN         NaN
# tt_010a                                                  NaN         NaN
# tt_010a                                                  NaN         NaN
#
#                                                  how_to_earn  \
# 0                                                       None
# 1                                                       None
# 2                                                       None
# 3                                                       None
# 4                                                       None
# 5                                                       None
# 6                                                       None
# 7                                                       None
# 8                                                       None
# 9                                                       None
# 10                                                      None
# 11                                                      None
# 12                                                      None
# 13                                                      None
# 14                                                      None
# 15                                                      None
# 16                                                      None
# 17                                                      None
# 18                                                      None
# 19         Unlocked in Blackrock Spire, in the Blackrock ...
# 20                                                      None
# 21                                                      None
# 22                                                      None
# 23                                                      None
# 24                                                      None
# 25                                                      None
# 26                                                      None
# 27                                                      None
# 28                                                      None
# 29          Unlocked in the Spire, in One Night in Karazhan.
# ...                                                      ...
# OG_338                                                   NaN
# OG_338                                                   NaN
# OG_339                                                   NaN
# OG_339                                                   NaN
# OG_339                                                   NaN
# OG_339                                                   NaN
# OG_340                                                   NaN
# OG_340                                                   NaN
# OG_340                                                   NaN
# OG_340                                                   NaN
# TB_OG_027                                                NaN
# TB_OG_027                                                NaN
# TB_OG_027                                                NaN
# TB_OG_027                                                NaN
# skele21                                                  NaN
# skele21                                                  NaN
# skele21                                                  NaN
# skele21                                                  NaN
# tt_004                                                   NaN
# tt_004                                                   NaN
# tt_004                                                   NaN
# tt_004                                                   NaN
# tt_010                                                   NaN
# tt_010                                                   NaN
# tt_010                                                   NaN
# tt_010                                                   NaN
# tt_010a                                                  NaN
# tt_010a                                                  NaN
# tt_010a                                                  NaN
# tt_010a                                                  NaN
#
#                                           how_to_earn_golden  \
# 0                                                       None
# 1                                                       None
# 2                                                       None
# 3                                                       None
# 4                                                       None
# 5                                                       None
# 6                                                       None
# 7                                                       None
# 8                                                       None
# 9                                                       None
# 10                                                      None
# 11                                                      None
# 12                                                      None
# 13                                                      None
# 14                                                      None
# 15                                                      None
# 16                                                      None
# 17                                                      None
# 18                                                      None
# 19         Crafting unlocked in Blackrock Spire, in the B...
# 20                                                      None
# 21                                                      None
# 22                                                      None
# 23                                                      None
# 24                                                      None
# 25                                                      None
# 26                                                      None
# 27                                                      None
# 28                                                      None
# 29         Crafting unlocked in the Spire, in One Night i...
# ...                                                      ...
# OG_338                                                   NaN
# OG_338                                                   NaN
# OG_339                                                   NaN
# OG_339                                                   NaN
# OG_339                                                   NaN
# OG_339                                                   NaN
# OG_340                                                   NaN
# OG_340                                                   NaN
# OG_340                                                   NaN
# OG_340                                                   NaN
# TB_OG_027                                                NaN
# TB_OG_027                                                NaN
# TB_OG_027                                                NaN
# TB_OG_027                                                NaN
# skele21                                                  NaN
# skele21                                                  NaN
# skele21                                                  NaN
# skele21                                                  NaN
# tt_004                                                   NaN
# tt_004                                                   NaN
# tt_004                                                   NaN
# tt_004                                                   NaN
# tt_010                                                   NaN
# tt_010                                                   NaN
# tt_010                                                   NaN
# tt_010                                                   NaN
# tt_010a                                                  NaN
# tt_010a                                                  NaN
# tt_010a                                                  NaN
# tt_010a                                                  NaN
#
#           targeting_arrow_text faction  durability             action  \
# 0                         None    None         NaN                NaN
# 1                         None    None         NaN                NaN
# 2                         None    None         NaN                NaN
# 3                         None    None         NaN                NaN
# 4                         None    None         NaN                NaN
# 5                         None    None         NaN                NaN
# 6                         None    None         NaN                NaN
# 7                         None    None         NaN                NaN
# 8                         None    None         NaN                NaN
# 9                         None    None         NaN                NaN
# 10                        None    None         NaN                NaN
# 11                        None    None         NaN                NaN
# 12                        None    None         NaN                NaN
# 13                        None    None         NaN                NaN
# 14                        None    None         NaN                NaN
# 15                        None    None         NaN                NaN
# 16                        None    None         NaN                NaN
# 17                        None    None         NaN                NaN
# 18                        None    None         NaN                NaN
# 19                        None    None         NaN                NaN
# 20                        None    None         NaN                NaN
# 21                        None    None         NaN                NaN
# 22                        None    None         NaN                NaN
# 23                        None    None         NaN                NaN
# 24                        None    None         NaN                NaN
# 25                        None    None         NaN                NaN
# 26                        None    None         NaN                NaN
# 27                        None    None         NaN                NaN
# 28                        None   HORDE         NaN                NaN
# 29                        None    None         NaN                NaN
# ...                        ...     ...         ...                ...
# OG_338                     NaN     NaN         NaN  DISENCHANT_NORMAL
# OG_338                     NaN     NaN         NaN  DISENCHANT_GOLDEN
# OG_339                     NaN     NaN         NaN    CRAFTING_NORMAL
# OG_339                     NaN     NaN         NaN    CRAFTING_GOLDEN
# OG_339                     NaN     NaN         NaN  DISENCHANT_NORMAL
# OG_339                     NaN     NaN         NaN  DISENCHANT_GOLDEN
# OG_340                     NaN     NaN         NaN    CRAFTING_NORMAL
# OG_340                     NaN     NaN         NaN    CRAFTING_GOLDEN
# OG_340                     NaN     NaN         NaN  DISENCHANT_NORMAL
# OG_340                     NaN     NaN         NaN  DISENCHANT_GOLDEN
# TB_OG_027                  NaN     NaN         NaN    CRAFTING_NORMAL
# TB_OG_027                  NaN     NaN         NaN    CRAFTING_GOLDEN
# TB_OG_027                  NaN     NaN         NaN  DISENCHANT_NORMAL
# TB_OG_027                  NaN     NaN         NaN  DISENCHANT_GOLDEN
# skele21                    NaN     NaN         NaN    CRAFTING_NORMAL
# skele21                    NaN     NaN         NaN    CRAFTING_GOLDEN
# skele21                    NaN     NaN         NaN  DISENCHANT_NORMAL
# skele21                    NaN     NaN         NaN  DISENCHANT_GOLDEN
# tt_004                     NaN     NaN         NaN    CRAFTING_NORMAL
# tt_004                     NaN     NaN         NaN    CRAFTING_GOLDEN
# tt_004                     NaN     NaN         NaN  DISENCHANT_NORMAL
# tt_004                     NaN     NaN         NaN  DISENCHANT_GOLDEN
# tt_010                     NaN     NaN         NaN    CRAFTING_NORMAL
# tt_010                     NaN     NaN         NaN    CRAFTING_GOLDEN
# tt_010                     NaN     NaN         NaN  DISENCHANT_NORMAL
# tt_010                     NaN     NaN         NaN  DISENCHANT_GOLDEN
# tt_010a                    NaN     NaN         NaN    CRAFTING_NORMAL
# tt_010a                    NaN     NaN         NaN    CRAFTING_GOLDEN
# tt_010a                    NaN     NaN         NaN  DISENCHANT_NORMAL
# tt_010a                    NaN     NaN         NaN  DISENCHANT_GOLDEN
#
#            cost_dust
# 0                NaN
# 1                NaN
# 2                NaN
# 3                NaN
# 4                NaN
# 5                NaN
# 6                NaN
# 7                NaN
# 8                NaN
# 9                NaN
# 10               NaN
# 11               NaN
# 12               NaN
# 13               NaN
# 14               NaN
# 15               NaN
# 16               NaN
# 17               NaN
# 18               NaN
# 19               NaN
# 20               NaN
# 21               NaN
# 22               NaN
# 23               NaN
# 24               NaN
# 25               NaN
# 26               NaN
# 27               NaN
# 28               NaN
# 29               NaN
# ...              ...
# OG_338         400.0
# OG_338        1600.0
# OG_339         100.0
# OG_339         800.0
# OG_339          20.0
# OG_339         100.0
# OG_340        1600.0
# OG_340        3200.0
# OG_340         400.0
# OG_340        1600.0
# TB_OG_027      100.0
# TB_OG_027      800.0
# TB_OG_027       20.0
# TB_OG_027      100.0
# skele21         40.0
# skele21        400.0
# skele21          5.0
# skele21         50.0
# tt_004          40.0
# tt_004         400.0
# tt_004           5.0
# tt_004          50.0
# tt_010         400.0
# tt_010        1600.0
# tt_010         100.0
# tt_010         400.0
# tt_010a        400.0
# tt_010a       1600.0
# tt_010a        100.0
# tt_010a        400.0
#
# [6859 rows x 20 columns]

# %% [markdown]
# Inspect the output above.  Note that the naming collision has been avoided by renaming the `cost` column from the right table to `cost_dust`.
#
# ## Summary
#
# In this lab, we learned how to:
#
# * Concatenate multiple DataFrames together into a single DataFrame
# * Use `sqlalchemy` to connect to a sqlite database and read in individual tables as DataFrames
# * Understand and execute the various types of joins (inner, outer, left, and right joins)
